# %%
import numpy as np
import pandas as pd
from math import pi
import matplotlib.pyplot as plt

# %matplotlib inline
pd.options.display.max_rows = 9999
pd.options.display.max_columns = 9999

# %%
fifa_15 = pd.read_csv("players_15.csv")
fifa_16 = pd.read_csv("players_16.csv")
fifa_17 = pd.read_csv("players_17.csv")
fifa_18 = pd.read_csv("players_18.csv")
fifa_19 = pd.read_csv("players_19.csv")
fifa_20 = pd.read_csv("players_20.csv")

# %%
fifa_15.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        169         67   Argentina  FC Barcelona       93         95
# 1        185         80    Portugal   Real Madrid       92         92
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0          0         0               CF           Left
# 1          0         0           LW, LM          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate body_type  \
# 0                         5          3            4  Medium/Low    Normal
# 1                         5          4            5    High/Low    Normal
#
#   real_face  release_clause_eur  \
# 0       Yes                 NaN
# 1       Yes                 NaN
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2018.0
# 1                 7.0         NaN  2009-07-01                2018.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              CF                  10.0  93.0      89.0     86.0       96.0
# 1              LW                   7.0  93.0      93.0     81.0       91.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       27.0    63.0        NaN          NaN         NaN          NaN
# 1       32.0    79.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (CPU AI Only), On...                 84
# 1  Power Free-Kick, Flair, Long Shot Taker (CPU A...                 83
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                94-3                         71                      89
# 1                95+3                         86                      82
#
#   attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# 0              85-5            96-1        89+2              90+4
# 1              87+2            93+3          88                79
#
#   skill_long_passing skill_ball_control movement_acceleration  \
# 0                 76                 96                    96
# 1                 72               92-3                    91
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                  90+2               94               94-2               95
# 1                    94               93                 90            63-12
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0             80-1            73          77-1             60
# 1               94            94            89             79
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0               88                   48                      22
# 1               93                   63                      24
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                  92-1               90                  76
# 1                  91+2               81                  85
#
#    mentality_composure defending_marking defending_standing_tackle  \
# 0                  NaN                25                        21
# 1                  NaN                22                        31
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                       20                  6                   11
# 1                       23                  7                   11
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                    8  89+3
# 1                  15                      14                   11  91+3
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3
# 1  91+3  91+3  89+3  91+3  91+3  91+3  89+3  89+3  89+3  89+3  87+3  77+3
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3
# 1  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3
#
#      rb
# 0  54+3
# 1  57+3

# %%
fifa_16.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   28  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   30  1985-02-05
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        170         72   Argentina  FC Barcelona       94         95
# 1        185         80    Portugal   Real Madrid       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0  111000000    550000           RW, CF           Left
# 1   85500000    475000           LW, LM          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate   body_type  \
# 0                         5          4            4  Medium/Low       Messi
# 1                         5          4            5    High/Low  C. Ronaldo
#
#   real_face  release_clause_eur  \
# 0       Yes                 NaN
# 1       Yes                 NaN
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #FK Specialist, #Acroba...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LM
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2018.0
# 1                 7.0         NaN  2009-07-01                2018.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              RW                  10.0  92.0      88.0     86.0       95.0
# 1              ST                   7.0  92.0      93.0     80.0       91.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       24.0    62.0        NaN          NaN         NaN          NaN
# 1       33.0    78.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (CPU AI Only), On...               80-4
# 1  Power Free-Kick, Flair, Long Shot Taker (CPU A...               82-1
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                93-1                         71                    88-1
# 1                  95                         86                    81-1
#
#   attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# 0                85              96          89                90
# 1                87              93          88              77-2
#
#   skill_long_passing skill_ball_control movement_acceleration  \
# 0               79+3                 96                  95-1
# 1                 72               91-1                    91
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                    90             92-2               92-2               95
# 1                  93-1             90-3               92+2             62-1
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0               80          68-5          76-1           59-1
# 1               94            94          87-2             79
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0               88                   48                      22
# 1               93                 62-1                    29+5
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                  90-2               90                  74
# 1                  93+2               81                  85
#
#    mentality_composure defending_marking defending_standing_tackle  \
# 0                  NaN             13-12                      23+2
# 1                  NaN                22                        31
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                     21+1                  6                   11
# 1                       23                  7                   11
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                    8  87+3
# 1                  15                      14                   11  91+3
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  87+3  87+3  91+3  91+3  91+3  91+3  91+3  91+3  91+3  91+3  90+3  82+3
# 1  91+3  91+3  90+3  91+3  91+3  91+3  90+3  88+3  88+3  88+3  88+3  80+3
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  82+3  82+3  90+3  62+3  57+3  57+3  57+3  62+3  57+3  44+3  44+3  44+3
# 1  80+3  80+3  88+3  64+3  60+3  60+3  60+3  64+3  60+3  52+3  52+3  52+3
#
#      rb
# 0  57+3
# 1  60+3

# %%
fifa_17.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   31  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   29  1987-06-24
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        185         80    Portugal   Real Madrid       94         94
# 1        170         72   Argentina  FC Barcelona       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   87000000    340000       LW, LM, ST          Right
# 1   89000000    340000               RW           Left
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            5       High/Low
# 1                         5          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur  \
# 0  C. Ronaldo       Yes                 NaN
# 1       Messi       Yes                 NaN
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 1  #Dribbler, #FK Specialist, #Acrobat, #Clinical...            RW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                 7.0         NaN  2009-07-01                2018.0
# 1                10.0         NaN  2004-07-01                2018.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              LS                   7.0  92.0      92.0     81.0       91.0
# 1              RW                  10.0  89.0      90.0     86.0       96.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       33.0    80.0        NaN          NaN         NaN          NaN
# 1       26.0    61.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits attacking_crossing  \
# 0  Power Free-Kick, Flair, Long Shot Taker (CPU A...               84+2
# 1  Finesse Shot, Long Shot Taker (CPU AI Only), S...               77-3
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                93-2                       87+1                    82+1
# 1                95+2                         71                      88
#
#   attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# 0              88+1              93        81-7                77
# 1                85            97+1          89                90
#
#   skill_long_passing skill_ball_control movement_acceleration  \
# 0                 72               92+1                    91
# 1               87+8               95-1                  92-3
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                  92-1               90               96+4             63+1
# 1                  87-3             90-2               95+3               95
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0               94          95+1          92+2           80+1
# 1             83+3            68          74-1             59
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0             92-1                 63+1                      29
# 1               88                   48                      22
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                  94+1             85+4                  85
# 1                  93+3               90                  74
#
#    mentality_composure defending_marking defending_standing_tackle  \
# 0                   86                22                        31
# 1                   94                13                      28+5
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                       23                  7                   11
# 1                     26+5                  6                   11
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                   11  92+3
# 1                  15                      14                    8  89+3
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  92+3  92+3  91+3  92+3  92+3  92+3  91+3  90+3  90+3  90+3  90+3  82+3
# 1  89+3  89+3  92+3  93+3  93+3  93+3  92+3  93+3  93+3  93+3  91+3  84+3
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  82+3  82+3  90+3  66+3  61+3  61+3  61+3  66+3  62+3  53+3  53+3  53+3
# 1  84+3  84+3  91+3  63+3  59+3  59+3  59+3  63+3  58+3  46+3  46+3  46+3
#
#      rb
# 0  62+3
# 1  58+3

# %%
fifa_18.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   32  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   30  1987-06-24
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        185         80    Portugal   Real Madrid       94         94
# 1        170         72   Argentina  FC Barcelona       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000           LW, ST          Right
# 1  105000000    565000               RW           Left
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            5       High/Low
# 1                         5          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur  \
# 0  C. Ronaldo       Yes         195800000.0
# 1       Messi       Yes         215300000.0
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 1  #Dribbler, #FK Specialist, #Acrobat, #Clinical...            RW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                 7.0         NaN  2009-07-01                2021.0
# 1                10.0         NaN  2004-07-01                2018.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              LS                   7.0  90.0      93.0     82.0       90.0
# 1              RW                  10.0  89.0      90.0     86.0       96.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       33.0    80.0        NaN          NaN         NaN          NaN
# 1       26.0    61.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits attacking_crossing  \
# 0  Power Free-Kick, Flair, Long Shot Taker (CPU A...               85+1
# 1  Finesse Shot, Long Shot Taker (CPU AI Only), S...                 77
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                94+1                       88+3                      83
# 1                  95                         71                      88
#
#   attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# 0                88            91-1          81                76
# 1                85              97          89                90
#
#   skill_long_passing skill_ball_control movement_acceleration  \
# 0                 77                 93                  89-2
# 1                 87                 95                    92
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                  91-1             89-1                 96               63
# 1                    87               90                 95               95
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0             94+2            95            92             80
# 1               85            68          73-1             59
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0             92+2                   63                      29
# 1               88                   48                      22
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                  95+1               85                  85
# 1                    93               90                  74
#
#   mentality_composure defending_marking defending_standing_tackle  \
# 0                95+9                22                        31
# 1                96+2                13                        28
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                       23                  7                   11
# 1                       26                  6                   11
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                   11  92+3
# 1                  15                      14                    8  89+3
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  92+3  92+3  91+3  92+3  92+3  92+3  91+3  90+3  90+3  90+3  90+3  83+3
# 1  89+3  89+3  92+3  93+3  93+3  93+3  92+3  93+3  93+3  93+3  91+3  84+3
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  83+3  83+3  90+3  66+3  62+3  62+3  62+3  66+3  62+3  53+3  53+3  53+3
# 1  84+3  84+3  91+3  62+3  59+3  59+3  59+3  62+3  58+3  46+3  46+3  46+3
#
#      rb
# 0  62+3
# 1  58+3

# %%
fifa_19.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
#
#           short_name                            long_name  age         dob  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   33  1985-02-05
# 1           L. Messi       Lionel Andrés Messi Cuccittini   31  1987-06-24
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        187         83    Portugal      Juventus       94         94
# 1        170         72   Argentina  FC Barcelona       94         94
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   77000000    405000           ST, LW          Right
# 1  110500000    565000       CF, RW, ST           Left
#
#    international_reputation  weak_foot  skill_moves      work_rate  \
# 0                         5          4            5       High/Low
# 1                         5          4            4  Medium/Medium
#
#     body_type real_face  release_clause_eur  \
# 0  C. Ronaldo       Yes         127100000.0
# 1       Messi       Yes         226500000.0
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 1  #Dribbler, #Distance Shooter, #FK Specialist, ...            RW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                 7.0         NaN  2018-07-10                2022.0
# 1                10.0         NaN  2004-07-01                2021.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              LS                   7.0  90.0      93.0     81.0       89.0
# 1              CF                  10.0  88.0      91.0     88.0       96.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       35.0    79.0        NaN          NaN         NaN          NaN
# 1       32.0    61.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits attacking_crossing  \
# 0  Power Free-Kick, Diver, Flair, Long Shot Taker...                 84
# 1  Finesse Shot, Long Shot Taker (CPU AI Only), S...                 77
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                  94                         89                      81
# 1                  95                         70                      90
#
#   attacking_volleys skill_dribbling skill_curve skill_fk_accuracy  \
# 0                87              88          81                76
# 1                86              97          93                94
#
#   skill_long_passing skill_ball_control movement_acceleration  \
# 0                 77                 94                    89
# 1                 87                 96                    91
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                    91               87                 96               70
# 1                    86               91                 95               95
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0               95            95            88             79
# 1               85            68            72             59
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0               93                   63                      29
# 1               94                   48                      22
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                    95               82                  85
# 1                    94               94                  75
#
#   mentality_composure defending_marking defending_standing_tackle  \
# 0                  95                28                        31
# 1                  96                33                        28
#
#   defending_sliding_tackle goalkeeping_diving goalkeeping_handling  \
# 0                       23                  7                   11
# 1                       26                  6                   11
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                   11  91+3
# 1                  15                      14                    8  88+2
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3
# 1  88+2  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2  93+2  90+2  84+2
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3
# 1  84+2  84+2  90+2  63+2  61+2  61+2  61+2  63+2  58+2  47+2  47+2  47+2
#
#      rb
# 0  61+3
# 1  58+2

# %%
fifa_20.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#    height_cm  weight_kg nationality          club  overall  potential  \
# 0        170         72   Argentina  FC Barcelona       94         94
# 1        187         83    Portugal      Juventus       93         93
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
#
#    international_reputation  weak_foot  skill_moves   work_rate   body_type  \
# 0                         5          4            4  Medium/Low       Messi
# 1                         5          4            5    High/Low  C. Ronaldo
#
#   real_face  release_clause_eur  \
# 0       Yes         195800000.0
# 1       Yes          96500000.0
#
#                                          player_tags team_position  \
# 0  #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2021.0
# 1                 7.0         NaN  2018-07-10                2022.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0             NaN                   NaN  87.0      92.0     92.0       96.0
# 1              LS                   7.0  90.0      93.0     82.0       89.0
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       39.0    66.0        NaN          NaN         NaN          NaN
# 1       35.0    78.0        NaN          NaN         NaN          NaN
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         37                        26                   6
# 1                         32                        24                   7
#
#    goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                    11                   15                       14
# 1                    11                   15                       14
#
#    goalkeeping_reflexes    ls    st    rs    lw    lf    cf    rf    rw   lam  \
# 0                     8  89+2  89+2  89+2  93+2  93+2  93+2  93+2  93+2  93+2
# 1                    11  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3
#
#     cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm   rdm   rwb  \
# 0  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2  66+2  68+2
# 1  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3  61+3  65+3
#
#      lb   lcb    cb   rcb    rb
# 0  63+2  52+2  52+2  52+2  63+2
# 1  61+3  53+3  53+3  53+3  61+3

# %%
fifa_15.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
fifa_15.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   15465.000000  15465.000000  15465.000000  15465.000000  15465.000000
# mean   189298.588425     24.763272    181.093631     75.482703     63.948594
# std     39648.820272      4.624565      6.635182      6.907243      7.208610
# min         2.000000     16.000000    155.000000     50.000000     40.000000
# 25%    178043.000000     21.000000    176.000000     70.000000     59.000000
# 50%    200844.000000     24.000000    181.000000     75.000000     64.000000
# 75%    214326.000000     28.000000    186.000000     80.000000     69.000000
# max    225562.000000     44.000000    203.000000    110.000000     93.000000
#
#           potential  value_eur  wage_eur  international_reputation  \
# count  15465.000000    15465.0   15465.0              15465.000000
# mean      68.483091        0.0       0.0                  1.126350
# std        6.611708        0.0       0.0                  0.401362
# min       40.000000        0.0       0.0                  1.000000
# 25%       64.000000        0.0       0.0                  1.000000
# 50%       68.000000        0.0       0.0                  1.000000
# 75%       73.000000        0.0       0.0                  1.000000
# max       95.000000        0.0       0.0                  5.000000
#
#           weak_foot   skill_moves  release_clause_eur  team_jersey_number  \
# count  15465.000000  15465.000000                 0.0        15233.000000
# mean       2.932363      2.267055                 NaN           19.803584
# std        0.652270      0.719035                 NaN           16.547682
# min        1.000000      1.000000                 NaN            1.000000
# 25%        3.000000      2.000000                 NaN            8.000000
# 50%        3.000000      2.000000                 NaN           17.000000
# 75%        3.000000      3.000000                 NaN           26.000000
# max        5.000000      5.000000                 NaN           99.000000
#
#        contract_valid_until  nation_jersey_number          pace      shooting  \
# count          15226.000000           1056.000000  13762.000000  13762.000000
# mean            2016.959740             12.026515     68.088432     51.671777
# std                2.069059              6.661003     11.004400     13.443599
# min             2014.000000              1.000000     22.000000     22.000000
# 25%             2015.000000              6.000000     62.000000     41.000000
# 50%             2016.000000             12.000000     69.000000     53.000000
# 75%             2019.000000             18.000000     76.000000     62.000000
# max             2021.000000             28.000000     97.000000     93.000000
#
#             passing     dribbling     defending        physic    gk_diving  \
# count  13762.000000  13762.000000  13762.000000  13762.000000  1703.000000
# mean      55.744223     60.617861     50.000799     64.602456    64.709336
# std       10.765868     10.800142     15.850317      9.698882     7.855747
# min       24.000000     25.000000     21.000000     28.000000    35.000000
# 25%       49.000000     54.000000     33.000000     58.000000    59.000000
# 50%       57.000000     62.000000     53.000000     66.000000    64.000000
# 75%       63.000000     68.000000     63.000000     72.000000    70.000000
# max       91.000000     96.000000     90.000000     91.000000    88.000000
#
#        gk_handling   gk_kicking  gk_reflexes     gk_speed  gk_positioning  \
# count  1703.000000  1703.000000  1703.000000  1703.000000     1703.000000
# mean     60.823840    59.455079    65.955373    43.900763       61.230182
# std       8.510626     8.689929     8.374343     8.440858        9.188257
# min      36.000000    21.000000    31.000000    20.000000       38.000000
# 25%      55.000000    53.000000    60.000000    39.000000       54.000000
# 50%      61.000000    59.000000    65.000000    44.000000       61.000000
# 75%      67.000000    65.000000    72.000000    49.000000       68.000000
# max      87.000000    92.000000    90.000000    66.000000       90.000000
#
#        mentality_composure
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
#Radar plot:
Messi = {'Pace':89,'Shooting':90,'Passing':86,'Dribbling':95,'Defending':26,'Physical':61}
Ronaldo = {'Pace':90,'Shooting':93,'Passing':82,'Dribbling':90,'Defending':33,'Physical':80}

# %%
radar_15 = fifa_15[["short_name", "pace", "shooting", "passing", "dribbling", "defending", "physic"]]
radar_15 = radar_15.set_index(["short_name"])
radar_15 = radar_15.dropna()
radar_15.head(2)
# Out:
#                    pace  shooting  passing  dribbling  defending  physic
# short_name
# L. Messi           93.0      89.0     86.0       96.0       27.0    63.0
# Cristiano Ronaldo  93.0      93.0     81.0       91.0       32.0    79.0

# %%
radar_15.describe()
# Out:
#                pace      shooting       passing     dribbling     defending  \
# count  13762.000000  13762.000000  13762.000000  13762.000000  13762.000000
# mean      68.088432     51.671777     55.744223     60.617861     50.000799
# std       11.004400     13.443599     10.765868     10.800142     15.850317
# min       22.000000     22.000000     24.000000     25.000000     21.000000
# 25%       62.000000     41.000000     49.000000     54.000000     33.000000
# 50%       69.000000     53.000000     57.000000     62.000000     53.000000
# 75%       76.000000     62.000000     63.000000     68.000000     63.000000
# max       97.000000     93.000000     91.000000     96.000000     90.000000
#
#              physic
# count  13762.000000
# mean      64.602456
# std        9.698882
# min       28.000000
# 25%       58.000000
# 50%       66.000000
# 75%       72.000000
# max       91.000000

# %%
# make a list out of the columns' names and call it Attributes
Attributes =list(radar_15)
AttNo = len(Attributes)

# %%
# Rondaldo's values
values = radar_15.iloc[1].tolist()
values += values [:1]
values
# Out:
# [93.0, 93.0, 81.0, 91.0, 32.0, 79.0, 93.0]

# %%
# Radar plot angles:
angles = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
angles += angles [:1]

# %%
ax = plt.subplot(111, polar=True)

#Add the attribute labels to our axes
plt.xticks(angles[:-1],Attributes)

#Plot the line around the outside of the filled area, using the angles and values calculated before
ax.plot(angles,values)

#Fill in the area plotted in the last line
ax.fill(angles, values, 'teal', alpha=0.1)

#Give the plot a title and show it
ax.set_title("Ronaldo")
plt.show()

# %%
#Find the values and angles for Messi
values2 = radar_15.iloc[0].tolist()
values2 += values2 [:1]

angles2 = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
angles2 += angles2 [:1]

# %%
#Create the chart as before, but with both Ronaldo's and Messi's angles/values
ax = plt.subplot(111, polar=True)

plt.xticks(angles[:-1],Attributes)

ax.plot(angles,values)
ax.fill(angles, values, 'teal', alpha=0.1)

ax.plot(angles2,values2)
ax.fill(angles2, values2, 'red', alpha=0.1)

#Rather than use a title, individual text points are added
plt.figtext(0.2,0.9,"Messi",color="red")
plt.figtext(0.2,0.85,"vs")
plt.figtext(0.2,0.8,"Ronaldo",color="teal")
plt.show()

# %%
# Creating a function to plot individual players
def createRadar(df, player):
    Attributes =list(radar_15)
    AttNo = len(Attributes)
    
    data = df.loc[player, :].tolist()
    data += data [:1]
    
    angles2 = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
    angles2 += angles2 [:1]
    
    ax = plt.subplot(111, polar=True)

    plt.xticks(angles[:-1],Attributes)
    ax.plot(angles,data)
    ax.fill(angles, data, 'blue', alpha=0.1)

    ax.set_title(player)
    plt.show()

# %%
#Example:
createRadar(radar_15, "L. Messi")

# %%
# Function to compare two players
def createRadar2(df1, player1, df2, player2):
    Attributes =list(radar_15)
    AttNo = len(Attributes)
    
    data = df1.loc[player1, :].tolist()
    data += data [:1]
    
    angles = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
    angles += angles [:1]
    
    data2 = df2.loc[player2, :].tolist()
    data2 += data2 [:1]
    
    angles2 = [n / float(AttNo) * 2 * pi for n in range(AttNo)]
    angles2 += angles2 [:1]
    
    ax = plt.subplot(111, polar=True)

    #Create the chart as before, but with both Ronaldo's and Messi's angles/values
    ax = plt.subplot(111, polar=True)

    plt.xticks(angles[:-1],Attributes)

    ax.plot(angles,data)
    ax.fill(angles, data, 'teal', alpha=0.1)

    ax.plot(angles2,data2)
    ax.fill(angles2, data2, 'red', alpha=0.1)

    #Rather than use a title, individual text points are added
    plt.figtext(0.2,0.9,player1,color="teal")
    plt.figtext(0.2,0.85,"vs")
    plt.figtext(0.2,0.8,player2,color="red")
    plt.show()

# %%
#example:
createRadar2(radar_15, "Cristiano Ronaldo", radar_15,"L. Messi");
# Out:
# C:\Users\Seno\Miniconda3\envs\code_red\lib\site-packages\ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
