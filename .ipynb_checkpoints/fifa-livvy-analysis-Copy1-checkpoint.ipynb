# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)
import matplotlib.cm as cm
import re
sns.set_style("darkgrid")
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
import re 
import statsmodels.api as sm

pd.set_option("display.max_columns", 100)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fifa_15 = pd.read_csv("players_15.csv")

# %% [markdown]
# ##### fifa_15.head()

# %%
fifa_16 = pd.read_csv("players_16.csv")

# %%
fifa_16.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/16...
# 3     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 4     176580  https://sofifa.com/player/176580/luis-suarez/1...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   28  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   30  1985-02-05
# 2          A. Robben                         Arjen Robben   31  1984-01-23
# 3           M. Neuer                         Manuel Neuer   29  1986-03-27
# 4          L. Suárez             Luis Alberto Suárez Díaz   28  1987-01-24
#
#    height_cm  weight_kg  nationality               club  overall  potential  \
# ...

# %%
def plot_chart(X, y, y_pred, x_l, x_h, y_l, y_h, c):
    plt.figure(figsize = (15,10))
    plt.scatter(X, y, color=c)
    plt.plot(X, y_pred, color='blue', linewidth=3)

# %%
fifa_16 = fifa_16[fifa_16['value_eur'] != 0]
X_2 = fifa_16['overall'].values.reshape(-1,1)
y_2 = fifa_16['value_eur'].values.reshape(-1,1)

poly = PolynomialFeatures(degree=2)
X_2_p = poly.fit_transform(X_2)
clf = linear_model.LinearRegression().fit(X_2_p, y_2)
y_2_pred = clf.predict(X_2_p)

print('Coefficients: ', clf.coef_)
print("Mean squared error: %.2f"% mean_squared_error(y_2, y_2_pred))
print('Variance score: %.2f'% r2_score(y_2, y_2_pred))

color_dict = {'ST': 'red', 'CF': 'red', 'LW': 'red', 'RW': 'red',

              'LM': 'blue', 'RM': 'blue', 'CM': 'blue', 'CAM': 'blue', 'CDM': 'blue',

              'LB': 'green', 'RB': 'green', 'CB': 'green', 'LWB': 'green', 'RWB': 'green',

              'GK': 'purple'}

c = fifa_16['team_position'].map(color_dict)
# Out:
# Coefficients:  [[       0.         -4296536.88706294    35412.0492395 ]]
# Mean squared error: 5071500387952.36
# Variance score: 0.71

# %%
#plot_chart(X_2, y_2, y_2_pred, 40, 100, 0, 130, 'black')
#
## by positions
#plot_chart(X_2, y_2, y_2_pred, 40, 100, 0, 130,c)
#
#
#plt.text(50, 120, 'Forward', c = 'red')x
#plt.text(50, 115, 'Midfielder', c = 'blue')
#plt.text(50, 110, 'Defender', c = 'green')
#plt.text(50, 105, 'Goalkeeper', c = 'purple')

# %%
fifa_16 = fifa_16[fifa_16['value_eur'] != 0]
X_2 = fifa_16['overall'].values.reshape(-1,1)
y_2 = fifa_16['value_eur'].values.reshape(-1,1)



c = fifa_16['team_position'].map(color_dict)


#plot_chart(X_2, y_2, c, 40, 100, 0, 130, c='black')


plt.figure(figsize = (15,10))
plt.scatter(X_2, y_2, color='b')

# %%
fifa_16 = fifa_16[fifa_16['value_eur'] != 0]
x = fifa_16['overall'].values.reshape(-1,1)
y = fifa_16['value_eur'].values.reshape(-1,1)

# %%
fifa_16 = fifa_16[["sofifa_id"
,"short_name"
,"age"
,"height_cm"
,"weight_kg"
,"nationality"
,"club"
,"overall"
,"value_eur"
,"wage_eur"
,"preferred_foot"
,"real_face"
,"player_positions"
,"team_jersey_number"
,"pace"
,"shooting"
,"passing"
,"dribbling"
,"defending"
,"physic"
,"attacking_heading_accuracy"
,"skill_fk_accuracy"
,"skill_ball_control"
,"movement_acceleration"
,"movement_sprint_speed"]]

# %%
fifa_16 = fifa_16.rename(columns={"sofifa_id": "id"
,"short_name" : "name"
,"age": "age"
,"height_cm" : "height"
,"weight_kg" : "weight"
,"nationality" : "nationality" 
,"club" : "club"
,"overall" : "rating"
,"value_eur" : "value_M"
,"wage_eur" : "wage_K"
,"preferred_foot" : "preferred_foot"
,"real_face" : "real_face"
,"player_positions" : "position"
,"team_jersey_number" : "jersey_number"
,"pace" : "pace"
,"shooting" : "shooting"
,"passing" : "passing"
,"dribbling" : "dribbling"
,"defending" : "defending"
,"physic" : "physic"
,"attacking_heading_accuracy" : "heading"
,"skill_fk_accuracy" : "free_kick"
,"skill_ball_control" : "ball_control"
,"movement_acceleration" : "acceleration"
,"movement_sprint_speed" : "speed"})

# %%
fifa_16["value_M"] = fifa_16["value_M"]/1000000

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0  550000           Left       Yes
# 1        Real Madrid      93     85.5  475000          Right       Yes
# 2  FC Bayern München      90     56.0  250000           Left       Yes
# 3  FC Bayern München      90     58.0  250000          Right       Yes
# 4       FC Barcelona      90     69.0  300000          Right       Yes
#
#      position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0      RW, CF           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
fifa_16["wage_K"] = fifa_16["wage_K"]/1000

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#      position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0      RW, CF           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
fifa_16.isna().sum()
# Out:
# id                   0
# name                 0
# age                  0
# height               0
# weight               0
# nationality          0
# club                 0
# rating               0
# value_M              0
# wage_K               0
# preferred_foot       0
# real_face            0
# position             0
# jersey_number        8
# pace              1589
# shooting          1589
# passing           1589
# dribbling         1589
# defending         1589
# physic            1589
# heading              0
# free_kick            0
# ball_control         0
# acceleration         0
# speed                0
# dtype: int64

# %%
fifa_16["position"].value_counts()
# Out:
# CB                  1730
# GK                  1589
# ST                  1568
# CM                   704
# LB                   631
#                     ...
# ST, RM, LM, CAM        1
# CDM, CM, RB, RM        1
# CAM, CM, CDM, LM       1
# LB, LWB, RB, RWB       1
# RM, CAM, CM, CDM       1
# Name: position, Length: 791, dtype: int64

# %%
fifa_16.fillna(0)
# Out:
#            id               name  age  height  weight  nationality  \
# 0      158023           L. Messi   28     170      72    Argentina
# 1       20801  Cristiano Ronaldo   30     185      80     Portugal
# 2        9014          A. Robben   31     180      80  Netherlands
# 3      167495           M. Neuer   29     193      92      Germany
# 4      176580          L. Suárez   28     182      85      Uruguay
# ...       ...                ...  ...     ...     ...          ...
# 14876  224867           R. Horne   19     180      76      England
# 14877  229852        C. Shephard   17     173      69        Wales
# 14878  227910           L. Gooch   17     181      65      England
# 14879  225339       S. Warburton   18     171      64      England
# 14880   11728      B. Richardson   45     185      77      England
#
#                     club  rating  value_M  wage_K preferred_foot real_face  \
# 0           FC Barcelona      94   111.00   550.0           Left       Yes
# ...

# %%
fifa_16.dtypes
# Out:
# id                  int64
# name               object
# age                 int64
# height              int64
# weight              int64
# nationality        object
# club               object
# rating              int64
# value_M           float64
# wage_K            float64
# preferred_foot     object
# real_face          object
# position           object
# jersey_number     float64
# pace              float64
# shooting          float64
# passing           float64
# dribbling         float64
# defending         float64
# physic            float64
# heading            object
# free_kick          object
# ball_control       object
# acceleration       object
# speed              object
# dtype: object

# %%
#fifa_16["position"].str.extract((r'^(\w+)\>'), expand=True)

fifa_16["position"] = fifa_16.position.str.extract((r'(\w+)'), expand=True)

fifa_16["position"].value_counts()
# Out:
# CB     2441
# ST     2197
# CM     1753
# GK     1589
# RB     1148
# CDM    1112
# LB     1101
# CAM     921
# LM      899
# RM      822
# RW      282
# LW      261
# CF       88
# LWB      23
# RWB      19
# Name: position, dtype: int64

# %%
#CB     
#ST  CF   
#CM CDM CAM   
#GK     
#RB       
#LB       
#LM LWB LW   
#RM RWB RW   
     
fifa_16["position"] = fifa_16["position"].replace({"CF" : "ST",
                                 "CDM" : "CM",
                                 "CAM" : "CM",
                                 "LWB" : "LM",
                                 "LW" : "LM",
                                 "RWB" : "RM",
                                 "RW" : "RM"})

# %%
fifa_16["position"].value_counts()
# Out:
# CM    3786
# CB    2441
# ST    2285
# GK    1589
# LM    1183
# RB    1148
# RM    1123
# LB    1101
# Name: position, dtype: int64

# %%
fifa_16["free_kick"] = fifa_16.free_kick.str.extract((r'(\d+)'), expand=True).astype(int)

# %%
fifa_16["heading"] = fifa_16.heading.str.extract((r'(\d+)'), expand=True).astype(int)

# %%
fifa_16["ball_control"] = fifa_16.ball_control.str.extract((r'(\d+)'), expand=True).astype(int)

# %%
fifa_16["acceleration"] = fifa_16.acceleration.str.extract((r'(\d+)'), expand=True).astype(int)

# %%
fifa_16["speed"] = fifa_16.speed.str.extract((r'(\d+)'), expand=True).astype(int)

# %%
fifa_16.dtypes
# Out:
# id                  int64
# name               object
# age                 int64
# height              int64
# weight              int64
# nationality        object
# club               object
# rating              int64
# value_M           float64
# wage_K            float64
# preferred_foot     object
# real_face          object
# position           object
# jersey_number     float64
# pace              float64
# shooting          float64
# passing           float64
# dribbling         float64
# defending         float64
# physic            float64
# heading             int64
# free_kick           int64
# ball_control        int64
# acceleration        int64
# speed               int64
# dtype: object

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0       RM           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
fifa_16["preferred_foot"].value_counts()
# Out:
# Right    11278
# Left      3378
# Name: preferred_foot, dtype: int64

# %%
#fifa_16.assign("right_foot"=np.where(fifa_16["preferred_foot"]=="Right",1,0))

# %%
pd.get_dummies(fifa_16["preferred_foot"], prefix="preferred_foot", drop_first=True)
# Out:
#        preferred_foot_Right
# 0                         0
# 1                         1
# 2                         0
# 3                         1
# 4                         1
# ...                     ...
# 14876                     1
# 14877                     1
# 14878                     1
# 14879                     0
# 14880                     1
#
# [14656 rows x 1 columns]

# %%
fifa_16 = pd.concat([fifa_16, pd.get_dummies(fifa_16["preferred_foot"], prefix="preferred_foot", drop_first=True)], axis=1 )

# %%
fifa_16.assign(const=1)
# Out:
#            id               name  age  height  weight  nationality  \
# 0      158023           L. Messi   28     170      72    Argentina
# 1       20801  Cristiano Ronaldo   30     185      80     Portugal
# 2        9014          A. Robben   31     180      80  Netherlands
# 3      167495           M. Neuer   29     193      92      Germany
# 4      176580          L. Suárez   28     182      85      Uruguay
# ...       ...                ...  ...     ...     ...          ...
# 14876  224867           R. Horne   19     180      76      England
# 14877  229852        C. Shephard   17     173      69        Wales
# 14878  227910           L. Gooch   17     181      65      England
# 14879  225339       S. Warburton   18     171      64      England
# 14880   11728      B. Richardson   45     185      77      England
#
#                     club  rating  value_M  wage_K preferred_foot real_face  \
# 0           FC Barcelona      94   111.00   550.0           Left       Yes
# ...

# %%
y = fifa_16["value_M"].values.reshape(-1,1)

X = fifa_16["preferred_foot_Right"].values.reshape(-1,1)

regr = linear_model.LinearRegression().fit(X,y)
y_pred = regr.predict(X)

print('Coefficients: ', regr.coef_)
print('Mean squared error: %.2f'% mean_squared_error(y, y_pred))
print('Variance score: %.2f'% r2_score(y, y_pred))
# Out:
# Coefficients:  [[-0.08441147]]
# Mean squared error: 17.62
# Variance score: 0.00

# %%
def plot_chart(X, y, y_pred, c):
    plt.figure(figsize = (15,10))
    plt.scatter(X, y, c =c)
    plt.plot(X, y_pred, c ='gray', linewidth=3)
    plt.title('Preferred foot vs Value')
    plt.ylabel('Value (Million)')
    plt.xlabel('Preferred foot')
plot_chart(X, y, y_pred,'lightblue')

# %%
y = fifa_16["value_M"].values.reshape(-1,1)

X = fifa_16["wage_K"].values.reshape(-1,1)

regr = linear_model.LinearRegression().fit(X,y)
y_pred = regr.predict(X)

print('Coefficients: ', regr.coef_)
print('Mean squared error: %.2f'% mean_squared_error(y, y_pred))
print('Variance score: %.2f'% r2_score(y, y_pred))
# Out:
# Coefficients:  [[0.1502182]]
# Mean squared error: 3.10
# Variance score: 0.82

# %%
def plot_chart(X, y, y_pred, c):
    plt.figure(figsize = (15,10))
    plt.scatter(X, y, c =c)
    plt.plot(X, y_pred, c ='gray', linewidth=3)
    plt.title('Wage vs Value')
    plt.ylabel('Value (Million)')
    plt.xlabel('Wage')
plot_chart(X, y, y_pred,'lightblue')

# %%
fifa_16 = fifa_16.assign(const=1)

# %%
variables = ["wage_K", "rating"]

# %%
#X = fifa_16[["const"] + variables]
#y = fifa_16["value_M"]
#log_reg = sm.Logit(y, X).fit()

# %%
X = fifa_16[["const"] + ["value_M"]]
y = fifa_16["preferred_foot_Right"]
log_reg = sm.Logit(y, X).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.201601
#          Iterations 5

# %%
log_reg.summary()
# Out:
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py:3409: RuntimeWarning:
#
# divide by zero encountered in double_scalars
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ...
# Dep. Variable:     preferred_foot_Right   No. Observations:                14656
# Model:                            Logit   Df Residuals:                    14654
# Method:                             MLE   Df Model:                            1
# Date:                  Thu, 13 Feb 2020   Pseudo R-squ.:                     inf
# ...

# %%
sns.regplot(x="value_M", y="preferred_foot_Right", data=fifa_16, logistic=True)

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0       RM           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
fifa_16["real_face"].value_counts()
# Out:
# No     13722
# Yes      934
# Name: real_face, dtype: int64

# %%
fifa_16 = pd.concat([fifa_16, pd.get_dummies(fifa_16["real_face"], prefix="real_face", drop_first=True)], axis=1 )

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0       RM           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
X = fifa_16[["const"] + ["value_M"]]
y = fifa_16["real_face_Yes"]
log_reg = sm.Logit(y, X).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 7
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py:1800: RuntimeWarning:
#
# divide by zero encountered in log
#
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/discrete/discrete_model.py:1747: RuntimeWarning:
#
# overflow encountered in exp

# %%
log_reg.summary()
# Out:
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# /usr/local/anaconda3/envs/code_red/lib/python3.7/site-packages/statsmodels/base/model.py:548: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:          real_face_Yes   No. Observations:                14656
# Model:                          Logit   Df Residuals:                    14654
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 13 Feb 2020   Pseudo R-squ.:                     inf
# Time:                        14:37:53   Log-Likelihood:                   -inf
# converged:                       True   LL-Null:                        0.0000
# ...

# %%
sns.regplot(x="value_M", y="real_face_Yes", data=fifa_16, logistic=True)

# %%
fifa_16.head()
# Out:
#        id               name  age  height  weight  nationality  \
# 0  158023           L. Messi   28     170      72    Argentina
# 1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2    9014          A. Robben   31     180      80  Netherlands
# 3  167495           M. Neuer   29     193      92      Germany
# 4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0       RM           10.0  92.0      88.0     86.0       95.0       24.0
# ...

# %%
fifa_16["position"].value_counts()
# Out:
# CM    3786
# CB    2441
# ST    2285
# GK    1589
# LM    1183
# RB    1148
# RM    1123
# LB    1101
# Name: position, dtype: int64

# %%
#The Overall Rating
plt.figure(figsize=(18,10))
sns.countplot(fifa_16['rating'], palette='rocket')
plt.show()

# %%
#ax, fig = plt.subplots(figsize=(16,9))
sns.jointplot(x=fifa_16["rating"], y=fifa_16["value_M"], data=fifa_16, height=16)

# %%
# Dream team within budget
## boxplots for ages vrs value_M
### position vrs value_M
#### rating vrs value_M

# %%
# formation will be 4-3-3
## CF, ST, LW, RW, CM, LM, RM, RCB, LCB, RDM, LDM, LB, RB, GK
## CF = ST , LW = LDM = LM , RW = RDM = RM, CM = CDM = CAM , RCB = LCB,

# %%
## ammount of players in the dream team

#CM    1
#CB    2
#ST    1
#GK    1
#LM    2
#RB    1
#RM    2
#LB    1

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="rating", y="value_M", data=fifa_16, fit_reg=False, hue='position', legend=True, height=16)
# Move the legend to an empty part of the plot
#plt.legend(loc='lower right')

# %%
# specifications 80-90 overall rating and 18-30 M per player

# %%
sns.lmplot( x="rating", y="value_M", data=fifa_16, fit_reg=False, hue='position', legend=True, height=16)
plt.ylim(0,33)
plt.xlim(75,91)
# Out:
# (75, 91)

# %%
fifa_20 = pd.read_csv("cleaned_fifa20.csv")

# %%
fifa_20_young = fifa_20.loc[fifa_20["age"] < 26]

# %%
fifa_20_young1 = fifa_20_young.loc[fifa_20_young['value_M'] <= 30.00]

# %%
 

fifa_20_young = fifa_20_young1[fifa_20_young1['rating'].between( 80, 91)]

# %%
fifa_20_young
# Out:
#      Unnamed: 0      id           name  age  height  weight  nationality  \
# 167         167  221087      Pau López   24     189      77        Spain
# 172         172  203574      J. Stones   25     188      70      England
# 174         174  210035       Grimaldo   23     171      69        Spain
# 179         179  200458       L. Digne   25     178      74       France
# 181         181  204935    J. Pickford   25     185      77      England
# ..          ...     ...            ...  ...     ...     ...          ...
# 462         462  225508      E. Bailly   25     186      77  Ivory Coast
# 463         463  230977     M. Almirón   25     174      63     Paraguay
# 464         464  235374     M. Lazzari   25     174      67        Italy
# 472         472  208141        Gabriel   25     187      82       Brazil
# 481         481  208128  H. Çalhanoğlu   25     178      76       Turkey
#
#                   club  rating  value_M  wage_K preferred_foot real_face  \
# ...

# %%
dt
# Out:
#       index  Unnamed: 0      id          name  age  height  weight  \
# 0        10          10  231747     K. Mbappé   20     178      73
# 1        12          12  202126       H. Kane   25     188      89
# 2        23          23  211110     P. Dybala   25     177      75
# 3        25          25  210257       Ederson   25     188      86
# 4        26          26  202652   R. Sterling   24     170      69
# ...     ...         ...     ...           ...  ...     ...     ...
# 9928  18272       18272  251789     P. Martin   20     188      84
# 9929  18273       18273  245006    Shao Shuai   22     186      79
# 9930  18274       18274  250995  Xiao Mingjie   22     177      66
# 9931  18275       18275  252332     Zhang Wei   19     186      75
# 9932  18276       18276  251110  Wang Haijian   18     185      74
#
#               nationality                           club  rating  value_M  \
# 0                  France            Paris Saint-Germain      89    93.50
# ...

# %%
hi.head()
# Out:
# 10    False
# 12     True
# 23    False
# 25    False
# 26    False
# dtype: bool

# %%
sns.lmplot( x="rating", y="value_M", data=fifa_20, fit_reg=False, hue='position', legend=True, height=16)
plt.ylim(0,33)
plt.xlim(79.5,91)
# Out:
# (79.5, 91)

# %%
fifa_files = ["players_16.csv","players_17.csv","players_18.csv", "players_19.csv", "players_20.csv"]

# %%
def clean(file):
    
    #read csv
    df = pd.read_csv(file)
    
    #pick variables for dataframe 
    
    df = df[["sofifa_id"
                        ,"short_name"
                        ,"age"
                        ,"height_cm"
                        ,"weight_kg"
                        ,"nationality"
                        ,"club"
                        ,"overall"
                        ,"value_eur"
                        ,"wage_eur"
                        ,"preferred_foot"
                        ,"real_face"
                        ,"player_positions"
                        ,"team_jersey_number"
                        ,"pace"
                        ,"shooting"
                        ,"passing"
                        ,"dribbling"
                        ,"defending"
                        ,"physic"
                        ,"attacking_heading_accuracy"
                        ,"skill_fk_accuracy"
                        ,"skill_ball_control"
                        ,"movement_acceleration"
                        ,"movement_sprint_speed"]]
    
    
     #renamed the variables
     
    df = df.rename(columns={"sofifa_id": "id"
                        ,"short_name" : "name"
                        ,"age": "age"
                        ,"height_cm" : "height"
                        ,"weight_kg" : "weight"
                        ,"nationality" : "nationality" 
                        ,"club" : "club"
                        ,"overall" : "rating"
                        ,"value_eur" : "value_M"
                        ,"wage_eur" : "wage_K"
                        ,"preferred_foot" : "preferred_foot"
                        ,"real_face" : "real_face"
                        ,"player_positions" : "position"
                        ,"team_jersey_number" : "jersey_number"
                        ,"pace" : "pace"
                        ,"shooting" : "shooting"
                        ,"passing" : "passing"
                        ,"dribbling" : "dribbling"
                        ,"defending" : "defending"
                        ,"physic" : "physic"
                        ,"attacking_heading_accuracy" : "heading"
                        ,"skill_fk_accuracy" : "free_kick"
                        ,"skill_ball_control" : "ball_control"
                        ,"movement_acceleration" : "acceleration"
                        ,"movement_sprint_speed" : "speed"})
                                
    
    # transform value into millions
    df["value_M"] = df["value_M"]/1000000
    
    
    #transform wage into thousands
    df["wage_K"] = df["wage_K"]/1000
    

    
    
    #regex the digits to extract 
    df["free_kick"] = df.free_kick.str.extract((r'(\d+)'), expand=True).astype(int)
    df["heading"] = df.heading.str.extract((r'(\d+)'), expand=True).astype(int)
    df["ball_control"] = df.ball_control.str.extract((r'(\d+)'), expand=True).astype(int)
    df["acceleration"] = df.acceleration.str.extract((r'(\d+)'), expand=True).astype(int)
    df["speed"] = df.speed.str.extract((r'(\d+)'), expand=True).astype(int)
    
    #get dummies for real face and concat to dataframe
    df = pd.concat([df, pd.get_dummies(df["real_face"], prefix="real_face", drop_first=True)], axis=1 )
    
    #get dummies for preferred_foot
    df = pd.concat([df, pd.get_dummies(df["preferred_foot"], prefix="preferred_foot", drop_first=True)], axis=1 )
    
    
    #extract position

    df["position"] = df.position.str.extract((r'(\w+)'), expand=True)
    
    # rename positions
    
    df["position"] = df["position"].replace({  "CF" : "ST",
                                               "CDM": "CM",
                                               "CAM": "CM",
                                               "LWB": "LM",
                                               "LW" : "LM",
                                               "RWB": "RM",
                                               "RW" : "RM"})
    
    return df

# %%
df = pd.read_csv("cleaned_players_16.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      id               name  age  height  weight  nationality  \
# 0           0  158023           L. Messi   28     170      72    Argentina
# 1           1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2           2    9014          A. Robben   31     180      80  Netherlands
# 3           3  167495           M. Neuer   29     193      92      Germany
# 4           4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# ...
