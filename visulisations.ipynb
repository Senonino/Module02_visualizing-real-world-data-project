# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.animation as animation
# %matplotlib inline

pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# %%
fifa_16 = pd.read_csv("cleaned_players_16.csv")

# %%
fifa_16.head()
# Out:
#    Unnamed: 0      id               name  age  height  weight  nationality  \
# 0           0  158023           L. Messi   28     170      72    Argentina
# 1           1   20801  Cristiano Ronaldo   30     185      80     Portugal
# 2           2    9014          A. Robben   31     180      80  Netherlands
# 3           3  167495           M. Neuer   29     193      92      Germany
# 4           4  176580          L. Suárez   28     182      85      Uruguay
#
#                 club  rating  value_M  wage_K preferred_foot real_face  \
# 0       FC Barcelona      94    111.0   550.0           Left       Yes
# 1        Real Madrid      93     85.5   475.0          Right       Yes
# 2  FC Bayern München      90     56.0   250.0           Left       Yes
# 3  FC Bayern München      90     58.0   250.0          Right       Yes
# 4       FC Barcelona      90     69.0   300.0          Right       Yes
#
#   position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0       RM           10.0  92.0      88.0     86.0       95.0       24.0
# 1       LM            7.0  92.0      93.0     80.0       91.0       33.0
# 2       RM           10.0  92.0      86.0     82.0       92.0       32.0
# 3       GK            1.0   NaN       NaN      NaN        NaN        NaN
# 4       ST            9.0  83.0      88.0     79.0       87.0       42.0
#
#    physic  heading  free_kick  ball_control  acceleration  speed  \
# 0    62.0       71         90            96            95     90
# 1    78.0       86         77            91            91     93
# 2    64.0       51         83            90            92     92
# 3     NaN       25         11            31            58     61
# 4    79.0       77         84            91            88     78
#
#    real_face_Yes  preferred_foot_Right
# 0              1                     0
# 1              1                     1
# 2              1                     0
# 3              1                     1
# 4              1                     1

# %%
fifa_16 = fifa_16.assign(year=2016)

# %%
fifa_17 = pd.read_csv("cleaned_players_17.csv")

# %%
fifa_17 = fifa_17.assign(year=2017)

# %%
fifa_17.dtypes
# Out:
# Unnamed: 0                int64
# id                        int64
# name                     object
# age                       int64
# height                    int64
# weight                    int64
# nationality              object
# club                     object
# rating                    int64
# value_M                 float64
# wage_K                  float64
# preferred_foot           object
# real_face                object
# position                 object
# jersey_number           float64
# pace                    float64
# shooting                float64
# passing                 float64
# dribbling               float64
# defending               float64
# physic                  float64
# heading                   int64
# free_kick                 int64
# ball_control              int64
# acceleration              int64
# speed                     int64
# real_face_Yes             int64
# preferred_foot_Right      int64
# year                      int64
# dtype: object

# %%
fifa_18 = pd.read_csv("cleaned_players_18.csv")

# %%
fifa_18 = fifa_18.assign(year=2018)

# %%
fifa_18.dtypes
# Out:
# Unnamed: 0                int64
# id                        int64
# name                     object
# age                       int64
# height                    int64
# weight                    int64
# nationality              object
# club                     object
# rating                    int64
# value_M                 float64
# wage_K                  float64
# preferred_foot           object
# real_face                object
# position                 object
# jersey_number           float64
# pace                    float64
# shooting                float64
# passing                 float64
# dribbling               float64
# defending               float64
# physic                  float64
# heading                   int64
# free_kick                 int64
# ball_control              int64
# acceleration              int64
# speed                     int64
# real_face_Yes             int64
# preferred_foot_Right      int64
# year                      int64
# dtype: object

# %%
fifa_19 = pd.read_csv("cleaned_players_19.csv")

# %%
fifa_19 = fifa_19.assign(year=2019)

# %%
fifa_19.dtypes
# Out:
# Unnamed: 0                int64
# id                        int64
# name                     object
# age                       int64
# height                    int64
# weight                    int64
# nationality              object
# club                     object
# rating                    int64
# value_M                 float64
# wage_K                  float64
# preferred_foot           object
# real_face                object
# position                 object
# jersey_number           float64
# pace                    float64
# shooting                float64
# passing                 float64
# dribbling               float64
# defending               float64
# physic                  float64
# heading                   int64
# free_kick                 int64
# ball_control              int64
# acceleration              int64
# speed                     int64
# real_face_Yes             int64
# preferred_foot_Right      int64
# year                      int64
# dtype: object

# %%
fifa_20 = pd.read_pickle("cleaned_fifa20.pkl")

# %%
fifa_20 = fifa_20.assign(year=2020)

# %%
fifa_20.dtypes
# Out:
# id                        int64
# name                     object
# age                       int64
# height                    int64
# weight                    int64
# nationality              object
# club                     object
# rating                    int64
# value_M                 float64
# wage_K                  float64
# preferred_foot           object
# real_face                object
# position                 object
# jersey_number           float64
# pace                    float64
# shooting                float64
# passing                 float64
# dribbling               float64
# defending               float64
# physic                  float64
# heading                   int64
# free_kick                 int64
# ball_control              int64
# acceleration              int64
# speed                     int64
# real_face_Yes             uint8
# preferred_foot_Right      uint8
# year                      int64
# dtype: object

# %%
fifa_17 = fifa_17.drop(columns="Unnamed: 0")

# %%
fifa_16 = fifa_16.drop(columns="Unnamed: 0")

# %%
fifa_18 = fifa_18.drop(columns="Unnamed: 0")

# %%
fifa_19 = fifa_19.drop(columns="Unnamed: 0")

# %%
dfs = (fifa_16,fifa_17,fifa_18,fifa_19,fifa_20)

# %%
df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
df
# Out:
#            id               name  age  height  weight  nationality  \
# 0      158023           L. Messi   28     170      72    Argentina
# 1       20801  Cristiano Ronaldo   30     185      80     Portugal
# 2        9014          A. Robben   31     180      80  Netherlands
# 3      167495           M. Neuer   29     193      92      Germany
# 4      176580          L. Suárez   28     182      85      Uruguay
# ...       ...                ...  ...     ...     ...          ...
# 85525  245006         Shao Shuai   22     186      79     China PR
# 85526  250995       Xiao Mingjie   22     177      66     China PR
# 85527  252332          Zhang Wei   19     186      75     China PR
# 85528  251110       Wang Haijian   18     185      74     China PR
# 85529  233449         Pan Ximing   26     182      78     China PR
#
#                                 club  rating  value_M  wage_K preferred_foot  \
# 0                       FC Barcelona      94   111.00   550.0           Left
# 1                        Real Madrid      93    85.50   475.0          Right
# 2                  FC Bayern München      90    56.00   250.0           Left
# 3                  FC Bayern München      90    58.00   250.0          Right
# 4                       FC Barcelona      90    69.00   300.0          Right
# ...                              ...     ...      ...     ...            ...
# 85525               Beijing Renhe FC      48     0.04     2.0          Right
# 85526               Shanghai SIPG FC      48     0.04     2.0          Right
# 85527         Hebei China Fortune FC      48     0.04     1.0          Right
# 85528  Shanghai Greenland Shenhua FC      48     0.04     1.0          Right
# 85529         Hebei China Fortune FC      48     0.04     2.0          Right
#
#       real_face position  jersey_number  pace  shooting  passing  dribbling  \
# 0           Yes       RM           10.0  92.0      88.0     86.0       95.0
# 1           Yes       LM            7.0  92.0      93.0     80.0       91.0
# 2           Yes       RM           10.0  92.0      86.0     82.0       92.0
# 3           Yes       GK            1.0   NaN       NaN      NaN        NaN
# 4           Yes       ST            9.0  83.0      88.0     79.0       87.0
# ...         ...      ...            ...   ...       ...      ...        ...
# 85525        No       CB           36.0  57.0      23.0     28.0       33.0
# 85526        No       CB           31.0  58.0      24.0     33.0       35.0
# 85527        No       CM           38.0  54.0      35.0     44.0       45.0
# 85528        No       CM           33.0  59.0      35.0     47.0       47.0
# 85529        No       CM           37.0  60.0      32.0     51.0       45.0
#
#        defending  physic  heading  free_kick  ball_control  acceleration  \
# 0           24.0    62.0       71         90            96            95
# 1           33.0    78.0       86         77            91            91
# 2           32.0    64.0       51         83            90            92
# 3            NaN     NaN       25         11            31            58
# 4           42.0    79.0       77         84            91            88
# ...          ...     ...      ...        ...           ...           ...
# 85525       47.0    51.0       40         21            35            56
# 85526       48.0    48.0       42         29            31            55
# 85527       48.0    51.0       49         32            49            55
# 85528       45.0    52.0       47         39            49            55
# 85529       47.0    55.0       48         35            46            54
#
#        speed  real_face_Yes  preferred_foot_Right  year
# 0         90              1                     0  2016
# 1         93              1                     1  2016
# 2         92              1                     0  2016
# 3         61              1                     1  2016
# 4         78              1                     1  2016
# ...      ...            ...                   ...   ...
# 85525     58              0                     1  2020
# 85526     61              0                     1  2020
# 85527     54              0                     1  2020
# 85528     63              0                     1  2020
# 85529     64              0                     1  2020
#
# [85530 rows x 28 columns]

# %%
df_messi = df[df.name.eq("L. Messi")]

# %%
df_crist = df[df.name.eq("Cristiano Ronaldo")]

# %%
df_messi
# Out:
#            id      name  age  height  weight nationality          club  \
# 0      158023  L. Messi   28     170      72   Argentina  FC Barcelona
# 14882  158023  L. Messi   29     170      72   Argentina  FC Barcelona
# 31891  158023  L. Messi   30     170      72   Argentina  FC Barcelona
# 49483  158023  L. Messi   31     170      72   Argentina  FC Barcelona
# 67252  158023  L. Messi   32     170      72   Argentina  FC Barcelona
#
#        rating  value_M  wage_K preferred_foot real_face position  \
# 0          94    111.0   550.0           Left       Yes       RM
# 14882      93     89.0   340.0           Left       Yes       RM
# 31891      93    105.0   565.0           Left       Yes       RM
# 49483      94    110.5   565.0           Left       Yes       ST
# 67252      94     95.5   565.0           Left       Yes       RM
#
#        jersey_number  pace  shooting  passing  dribbling  defending  physic  \
# 0               10.0  92.0      88.0     86.0       95.0       24.0    62.0
# 14882           10.0  89.0      90.0     86.0       96.0       26.0    61.0
# 31891           10.0  89.0      90.0     86.0       96.0       26.0    61.0
# 49483           10.0  88.0      91.0     88.0       96.0       32.0    61.0
# 67252           10.0  87.0      92.0     92.0       96.0       39.0    66.0
#
#        heading  free_kick  ball_control  acceleration  speed  real_face_Yes  \
# 0           71         90            96            95     90              1
# 14882       71         90            95            92     87              1
# 31891       71         90            95            92     87              1
# 49483       70         94            96            91     86              1
# 67252       70         94            96            91     84              1
#
#        preferred_foot_Right  year
# 0                         0  2016
# 14882                     0  2017
# 31891                     0  2018
# 49483                     0  2019
# 67252                     0  2020

# %%
df_k = df[df.name.eq("K. Mbappé")]

# %%
df_k
# Out:
#            id       name  age  height  weight nationality  \
# 32016  231747  K. Mbappé   18     178      73      France
# 49523  231747  K. Mbappé   19     178      73      France
# 67262  231747  K. Mbappé   20     178      73      France
#
#                       club  rating  value_M  wage_K preferred_foot real_face  \
# 32016  Paris Saint-Germain      83     41.5    31.0          Right       Yes
# 49523  Paris Saint-Germain      87     72.0    83.0          Right       Yes
# 67262  Paris Saint-Germain      89     93.5   155.0          Right       Yes
#
#       position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 32016       ST           29.0  90.0      80.0     74.0       85.0       47.0
# 49523       RM            7.0  96.0      81.0     79.0       89.0       39.0
# 67262       ST            7.0  96.0      84.0     78.0       90.0       39.0
#
#        physic  heading  free_kick  ball_control  acceleration  speed  \
# 32016    74.0       76         58            87            89     90
# 49523    72.0       77         63            90            96     96
# 67262    75.0       77         63            90            96     96
#
#        real_face_Yes  preferred_foot_Right  year
# 32016              1                     1  2018
# 49523              1                     1  2019
# 67262              1                     1  2020

# %%
df_p = df[df.club.eq("Paris Saint-Germain")]

# %%
df_p
# Out:
#            id            name  age  height  weight nationality  \
# 6       41236  Z. Ibrahimović   33     195      95      Sweden
# 8      164240    Thiago Silva   30     183      79      Brazil
# 47     179813       E. Cavani   28     184      71     Uruguay
# 49     183898     A. Di María   27     180      75   Argentina
# 51     199556     M. Verratti   22     165      60       Italy
# ...       ...             ...  ...     ...     ...         ...
# 80387  247871         M. Kapo   18     183      75      France
# 80431  241495     A. Toufiqui   20     175      69      France
# 81410  234401       I. Hemans   22     168      64       Ghana
# 81885  243710     G. Innocent   19     190      80      France
# 81907  238186        M. Bułka   19     199      90      Poland
#
#                       club  rating  value_M  wage_K preferred_foot real_face  \
# 6      Paris Saint-Germain      89   40.500   220.0          Right       Yes
# 8      Paris Saint-Germain      88   38.000   200.0          Right       Yes
# 47     Paris Saint-Germain      85   33.500   200.0          Right       Yes
# 49     Paris Saint-Germain      85   34.000   200.0           Left       Yes
# 51     Paris Saint-Germain      84   38.000   140.0          Right       Yes
# ...                    ...     ...      ...     ...            ...       ...
# 80387  Paris Saint-Germain      62    0.600     3.0          Right        No
# 80431  Paris Saint-Germain      62    0.650     8.0           Left        No
# 81410  Paris Saint-Germain      61    0.400     8.0           Left        No
# 81885  Paris Saint-Germain      60    0.375     3.0          Right        No
# 81907  Paris Saint-Germain      60    0.375     3.0          Right        No
#
#       position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 6           ST           10.0  73.0      90.0     81.0       85.0       31.0
# 8           CB            2.0  74.0      57.0     73.0       73.0       90.0
# 47          ST            9.0  76.0      83.0     71.0       81.0       42.0
# 49          CM           11.0  88.0      79.0     83.0       86.0       49.0
# 51          CM            6.0  68.0      58.0     83.0       87.0       78.0
# ...        ...            ...   ...       ...      ...        ...        ...
# 80387       CM           39.0  66.0      46.0     56.0       62.0       61.0
# 80431       CM           41.0  64.0      52.0     62.0       63.0       55.0
# 81410       LB           46.0  79.0      41.0     53.0       67.0       57.0
# 81885       GK           40.0   NaN       NaN      NaN        NaN        NaN
# 81907       GK           30.0   NaN       NaN      NaN        NaN        NaN
#
#        physic  heading  free_kick  ball_control  acceleration  speed  \
# 6        86.0       76         80            90            72     74
# 8        79.0       82         73            80            72     76
# 47       80.0       86         77            83            74     78
# 49       70.0       53         72            86            88     88
# 51       69.0       55         64            85            72     64
# ...       ...      ...        ...           ...           ...    ...
# 80387    59.0       58         42            64            65     67
# 80431    54.0       51         45            63            63     65
# 81410    51.0       44         60            65            78     79
# 81885     NaN       11         11            15            30     31
# 81907     NaN       10         14            13            28     25
#
#        real_face_Yes  preferred_foot_Right  year
# 6                  1                     1  2016
# 8                  1                     1  2016
# 47                 1                     1  2016
# 49                 1                     0  2016
# 51                 1                     1  2016
# ...              ...                   ...   ...
# 80387              0                     1  2020
# 80431              0                     0  2020
# 81410              0                     0  2020
# 81885              0                     1  2020
# 81907              0                     1  2020
#
# [149 rows x 28 columns]

# %%
p16 = fifa_16[fifa_16.club.eq("Paris Saint-Germain")].reset_index(drop=True)[0:11]

# %%
p17 = fifa_17[fifa_17.club.eq("Paris Saint-Germain")].reset_index(drop=True)[0:11]

# %%
p18 = fifa_18[fifa_18.club.eq("Paris Saint-Germain")].reset_index(drop=True)[0:11]

# %%
p19 = fifa_19[fifa_19.club.eq("Paris Saint-Germain")].reset_index(drop=True)[0:11]

# %%
p20 = fifa_20[fifa_20.club.eq("Paris Saint-Germain")].reset_index(drop=True)[0:11]

# %%
dfs = [p16,p17,p18,p19,p20]

# %%
paris = pd.concat(dfs, axis=0, ignore_index=True)

# %%
paris
# Out:
#         id            name  age  height  weight  nationality  \
# 0    41236  Z. Ibrahimović   33     195      95       Sweden
# 1   164240    Thiago Silva   30     183      79       Brazil
# 2   179813       E. Cavani   28     184      71      Uruguay
# 3   183898     A. Di María   27     180      75    Argentina
# 4   199556     M. Verratti   22     165      60        Italy
# 5   191180      J. Pastore   26     187      78    Argentina
# 6   170890      B. Matuidi   28     175      70       France
# 7   179944      David Luiz   28     189      84       Brazil
# 8   188943        K. Trapp   24     189      88      Germany
# 9   200949           Lucas   22     172      72       Brazil
# 10  168435       S. Sirigu   28     192      80        Italy
# 11  164240    Thiago Silva   31     183      79       Brazil
# 12  183898     A. Di María   28     180      75    Argentina
# 13  170890      B. Matuidi   29     175      70       France
# 14  199556     M. Verratti   23     165      60        Italy
# 15  191180      J. Pastore   27     187      78    Argentina
# 16  179813       E. Cavani   29     184      71      Uruguay
# 17  197242   G. Krychowiak   26     186      85       Poland
# 18  161648     H. Ben Arfa   29     178      74       France
# 19  197853       S. Aurier   23     176      76  Ivory Coast
# 20  188943        K. Trapp   25     189      88      Germany
# 21  207865      Marquinhos   22     183      75       Brazil
# 22  190871          Neymar   25     175      68       Brazil
# 23  164240    Thiago Silva   32     183      79       Brazil
# 24  199556     M. Verratti   24     165      60        Italy
# 25  179813       E. Cavani   30     184      71      Uruguay
# 26  183898     A. Di María   29     180      75    Argentina
# 27  202166      J. Draxler   23     187      72      Germany
# 28  146530      Dani Alves   34     172      68       Brazil
# 29  231747       K. Mbappé   18     178      73       France
# 30  207865      Marquinhos   23     183      75       Brazil
# 31  191180      J. Pastore   28     187      78    Argentina
# 32  200949           Lucas   24     172      72       Brazil
# 33  190871       Neymar Jr   26     175      68       Brazil
# 34  179813       E. Cavani   31     185      77      Uruguay
# 35    1179       G. Buffon   40     192      92        Italy
# 36  164240    Thiago Silva   33     183      82       Brazil
# 37  231747       K. Mbappé   19     178      73       France
# 38  199556     M. Verratti   25     165      60        Italy
# 39  207865      Marquinhos   24     183      75       Brazil
# 40  183898     A. Di María   30     180      69    Argentina
# 41  225850     P. Kimpembe   22     189      80       France
# 42  210008       A. Rabiot   23     192      80       France
# 43  202166      J. Draxler   24     187      77      Germany
# 44  190871       Neymar Jr   27     175      68       Brazil
# 45  231747       K. Mbappé   20     178      73       France
# 46  179813       E. Cavani   32     185      77      Uruguay
# 47  164240    Thiago Silva   34     183      82       Brazil
# 48  207865      Marquinhos   25     183      75       Brazil
# 49  199556     M. Verratti   26     165      60        Italy
# 50  183898     A. Di María   31     180      69    Argentina
# 51  202166      J. Draxler   25     187      77      Germany
# 52  198950   Pablo Sarabia   27     174      70        Spain
# 53  193474        I. Gueye   29     174      66      Senegal
# 54  225850     P. Kimpembe   23     189      80       France
#
#                    club  rating  value_M  wage_K preferred_foot real_face  \
# 0   Paris Saint-Germain      89     40.5   220.0          Right       Yes
# 1   Paris Saint-Germain      88     38.0   200.0          Right       Yes
# 2   Paris Saint-Germain      85     33.5   200.0          Right       Yes
# 3   Paris Saint-Germain      85     34.0   200.0           Left       Yes
# 4   Paris Saint-Germain      84     38.0   140.0          Right       Yes
# 5   Paris Saint-Germain      84     34.5   180.0          Right       Yes
# 6   Paris Saint-Germain      84     25.5   180.0           Left       Yes
# 7   Paris Saint-Germain      83     21.0   170.0          Right       Yes
# 8   Paris Saint-Germain      82     21.5   120.0          Right        No
# 9   Paris Saint-Germain      82     26.0   130.0          Right       Yes
# 10  Paris Saint-Germain      82     17.5   150.0          Right       Yes
# 11  Paris Saint-Germain      89     39.5   160.0          Right       Yes
# 12  Paris Saint-Germain      87     45.0   170.0           Left       Yes
# 13  Paris Saint-Germain      86     29.5   120.0           Left       Yes
# 14  Paris Saint-Germain      85     44.0   110.0          Right       Yes
# 15  Paris Saint-Germain      85     36.5   130.0          Right       Yes
# 16  Paris Saint-Germain      85     32.5   120.0          Right       Yes
# 17  Paris Saint-Germain      84     28.5   130.0          Right        No
# 18  Paris Saint-Germain      84     27.5   110.0           Left       Yes
# 19  Paris Saint-Germain      83     26.5    90.0          Right        No
# 20  Paris Saint-Germain      83     24.5    90.0          Right        No
# 21  Paris Saint-Germain      82     23.5    70.0          Right       Yes
# 22  Paris Saint-Germain      92    123.0   280.0          Right       Yes
# 23  Paris Saint-Germain      88     34.0   175.0          Right       Yes
# 24  Paris Saint-Germain      87     64.5   130.0          Right       Yes
# 25  Paris Saint-Germain      87     48.5   160.0          Right       Yes
# 26  Paris Saint-Germain      85     37.5   145.0           Left       Yes
# 27  Paris Saint-Germain      84     39.5   120.0          Right       Yes
# 28  Paris Saint-Germain      84      9.0   115.0          Right       Yes
# 29  Paris Saint-Germain      83     41.5    31.0          Right       Yes
# 30  Paris Saint-Germain      83     30.5    75.0          Right       Yes
# 31  Paris Saint-Germain      83     25.5   100.0          Right       Yes
# 32  Paris Saint-Germain      82     28.0    92.0          Right       Yes
# 33  Paris Saint-Germain      92    118.5   290.0          Right       Yes
# 34  Paris Saint-Germain      89     60.0   200.0          Right       Yes
# 35  Paris Saint-Germain      88      4.0    77.0          Right       Yes
# 36  Paris Saint-Germain      88     24.0   165.0          Right       Yes
# 37  Paris Saint-Germain      87     72.0    83.0          Right       Yes
# 38  Paris Saint-Germain      86     55.0   135.0          Right       Yes
# 39  Paris Saint-Germain      84     35.5    90.0          Right       Yes
# 40  Paris Saint-Germain      84     29.5   125.0           Left       Yes
# 41  Paris Saint-Germain      83     30.5    82.0           Left        No
# 42  Paris Saint-Germain      83     33.0    91.0           Left       Yes
# 43  Paris Saint-Germain      83     32.5    91.0          Right       Yes
# 44  Paris Saint-Germain      92    105.5   290.0          Right       Yes
# 45  Paris Saint-Germain      89     93.5   155.0          Right       Yes
# 46  Paris Saint-Germain      88     47.0   195.0          Right       Yes
# 47  Paris Saint-Germain      87     18.5   135.0          Right       Yes
# 48  Paris Saint-Germain      86     51.5   120.0          Right       Yes
# 49  Paris Saint-Germain      86     54.5   140.0          Right       Yes
# 50  Paris Saint-Germain      86     39.0   150.0           Left       Yes
# 51  Paris Saint-Germain      83     32.5   100.0          Right       Yes
# 52  Paris Saint-Germain      83     29.5   105.0           Left       Yes
# 53  Paris Saint-Germain      83     22.0   100.0          Right       Yes
# 54  Paris Saint-Germain      82     26.5    75.0           Left       Yes
#
#    position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 0        ST           10.0  73.0      90.0     81.0       85.0       31.0
# 1        CB            2.0  74.0      57.0     73.0       73.0       90.0
# 2        ST            9.0  76.0      83.0     71.0       81.0       42.0
# 3        CM           11.0  88.0      79.0     83.0       86.0       49.0
# 4        CM            6.0  68.0      58.0     83.0       87.0       78.0
# 5        CM           27.0  74.0      77.0     84.0       86.0       58.0
# 6        CM           14.0  75.0      67.0     77.0       75.0       83.0
# 7        CB           32.0  73.0      64.0     73.0       73.0       83.0
# 8        GK           16.0   NaN       NaN      NaN        NaN        NaN
# 9        RM            7.0  93.0      73.0     75.0       87.0       44.0
# 10       GK           30.0   NaN       NaN      NaN        NaN        NaN
# 11       CB            2.0  74.0      57.0     73.0       73.0       90.0
# 12       RM           11.0  87.0      79.0     84.0       87.0       47.0
# 13       CM           14.0  79.0      67.0     78.0       76.0       83.0
# 14       CM            6.0  68.0      58.0     83.0       87.0       78.0
# 15       CM           10.0  74.0      77.0     84.0       86.0       58.0
# 16       ST            9.0  76.0      83.0     71.0       79.0       42.0
# 17       CM           23.0  70.0      58.0     73.0       67.0       81.0
# 18       CM           21.0  82.0      82.0     79.0       88.0       40.0
# 19       RB           19.0  85.0      66.0     73.0       77.0       80.0
# 20       GK            1.0   NaN       NaN      NaN        NaN        NaN
# 21       CB            5.0  73.0      38.0     67.0       69.0       84.0
# 22       LM           10.0  92.0      84.0     79.0       95.0       30.0
# 23       CB            2.0  72.0      56.0     73.0       73.0       89.0
# 24       CM            6.0  65.0      59.0     84.0       89.0       79.0
# 25       ST            9.0  77.0      83.0     72.0       80.0       42.0
# 26       RM           11.0  86.0      77.0     82.0       86.0       47.0
# 27       LM           23.0  78.0      80.0     82.0       86.0       34.0
# 28       RB           32.0  82.0      68.0     81.0       85.0       77.0
# 29       ST           29.0  90.0      80.0     74.0       85.0       47.0
# 30       CB            5.0  71.0      38.0     68.0       69.0       84.0
# 31       CM           27.0  71.0      75.0     83.0       85.0       58.0
# 32       RM            7.0  93.0      74.0     75.0       86.0       45.0
# 33       LM           10.0  92.0      84.0     83.0       95.0       32.0
# 34       ST            9.0  76.0      87.0     72.0       80.0       52.0
# 35       GK            1.0   NaN       NaN      NaN        NaN        NaN
# 36       CB            2.0  71.0      54.0     73.0       69.0       88.0
# 37       RM            7.0  96.0      81.0     79.0       89.0       39.0
# 38       CM            6.0  65.0      60.0     84.0       89.0       79.0
# 39       CB            5.0  75.0      38.0     69.0       67.0       85.0
# 40       RM           11.0  85.0      76.0     82.0       85.0       47.0
# 41       CB            3.0  77.0      39.0     67.0       67.0       82.0
# 42       CM           25.0  74.0      74.0     79.0       80.0       77.0
# 43       CM           23.0  77.0      80.0     82.0       87.0       55.0
# 44       LM           10.0  91.0      85.0     87.0       95.0       32.0
# 45       ST            7.0  96.0      84.0     78.0       90.0       39.0
# 46       ST            9.0  75.0      86.0     72.0       79.0       55.0
# 47       CB            2.0  62.0      54.0     72.0       72.0       87.0
# 48       CB            5.0  74.0      41.0     73.0       70.0       86.0
# 49       CM            6.0  65.0      60.0     84.0       90.0       79.0
# 50       RM           11.0  84.0      79.0     84.0       87.0       48.0
# 51       CM           23.0  77.0      79.0     81.0       86.0       55.0
# 52       CM           19.0  75.0      76.0     82.0       84.0       57.0
# 53       CM           27.0  73.0      59.0     70.0       78.0       85.0
# 54       CB            3.0  75.0      39.0     67.0       67.0       81.0
#
#     physic  heading  free_kick  ball_control  acceleration  speed  \
# 0     86.0       76         80            90            72     74
# 1     79.0       82         73            80            72     76
# 2     80.0       86         77            83            74     78
# 3     70.0       53         72            86            88     88
# 4     69.0       55         64            85            72     64
# 5     68.0       63         69            87            72     75
# 6     81.0       73         52            77            74     76
# 7     77.0       83         76            79            72     73
# 8      NaN       11         12            24            45     52
# 9     62.0       50         68            84            95     91
# 10     NaN       11         11            18            50     51
# 11    79.0       82         73            80            72     76
# 12    70.0       53         72            87            86     88
# 13    84.0       73         52            79            79     79
# 14    68.0       55         64            85            72     64
# 15    68.0       63         69            87            72     75
# 16    80.0       88         74            79            74     78
# 17    87.0       83         62            77            66     73
# 18    74.0       65         75            86            84     80
# 19    85.0       77         30            79            84     85
# 20     NaN       11         12            24            45     52
# 21    76.0       78         32            76            73     73
# 22    60.0       62         84            95            94     90
# 23    79.0       82         67            80            70     74
# 24    68.0       55         64            88            69     62
# 25    81.0       88         74            80            75     78
# 26    68.0       53         72            85            86     86
# 27    64.0       65         75            87            76     79
# 28    66.0       72         74            86            79     84
# 29    74.0       76         58            87            89     90
# 30    76.0       80         32            76            69     72
# 31    64.0       63         69            87            69     72
# 32    62.0       50         74            82            95     92
# 33    59.0       62         87            95            94     90
# 34    83.0       89         76            82            75     76
# 35     NaN       13         13            28            49     43
# 36    79.0       81         64            80            70     72
# 37    72.0       77         63            90            96     96
# 38    66.0       55         64            88            69     62
# 39    76.0       80         32            76            73     76
# 40    66.0       51         82            84            86     85
# 41    83.0       79         32            78            75     78
# 42    79.0       77         59            83            73     74
# 43    64.0       65         76            89            78     77
# 44    58.0       62         87            95            94     89
# 45    75.0       77         63            90            96     96
# 46    83.0       89         76            81            74     76
# 47    78.0       81         61            80            60     64
# 48    77.0       84         32            79            72     76
# 49    66.0       55         64            89            69     61
# 50    68.0       51         88            86            85     84
# 51    63.0       65         76            88            78     77
# 52    57.0       61         74            85            74     75
# 53    78.0       69         61            79            74     72
# 54    83.0       79         32            78            73     77
#
#     real_face_Yes  preferred_foot_Right  year
# 0               1                     1  2016
# 1               1                     1  2016
# 2               1                     1  2016
# 3               1                     0  2016
# 4               1                     1  2016
# 5               1                     1  2016
# 6               1                     0  2016
# 7               1                     1  2016
# 8               0                     1  2016
# 9               1                     1  2016
# 10              1                     1  2016
# 11              1                     1  2017
# 12              1                     0  2017
# 13              1                     0  2017
# 14              1                     1  2017
# 15              1                     1  2017
# 16              1                     1  2017
# 17              0                     1  2017
# 18              1                     0  2017
# 19              0                     1  2017
# 20              0                     1  2017
# 21              1                     1  2017
# 22              1                     1  2018
# 23              1                     1  2018
# 24              1                     1  2018
# 25              1                     1  2018
# 26              1                     0  2018
# 27              1                     1  2018
# 28              1                     1  2018
# 29              1                     1  2018
# 30              1                     1  2018
# 31              1                     1  2018
# 32              1                     1  2018
# 33              1                     1  2019
# 34              1                     1  2019
# 35              1                     1  2019
# 36              1                     1  2019
# 37              1                     1  2019
# 38              1                     1  2019
# 39              1                     1  2019
# 40              1                     0  2019
# 41              0                     0  2019
# 42              1                     0  2019
# 43              1                     1  2019
# 44              1                     1  2020
# 45              1                     1  2020
# 46              1                     1  2020
# 47              1                     1  2020
# 48              1                     1  2020
# 49              1                     1  2020
# 50              1                     0  2020
# 51              1                     1  2020
# 52              1                     0  2020
# 53              1                     1  2020
# 54              1                     0  2020

# %%
#g = sns.scatterplot(x="age",y="value_M", hue="year", data=paris, size="rating")
#
#g.fig.set_size_inches(15,15)

# %%
#fig, axes = plt.subplots(3,1,figsize=(10,18))
#plt.scatterplot(x='age', y='value_M', hue='year', size='rating', data=paris)
##plt.axis('equal')
#plt.show()

# %%
sns.lmplot( x="age", y="value_M", data=paris, fit_reg=False, hue='year', legend=True, height=16)

# %%
df_n = df[df.id.eq(190871)]

# %%
df_n
# Out:
#            id       name  age  height  weight nationality  \
# 7      190871     Neymar   23     174      68      Brazil
# 14883  190871     Neymar   24     174      68      Brazil
# 31892  190871     Neymar   25     175      68      Brazil
# 49484  190871  Neymar Jr   26     175      68      Brazil
# 67254  190871  Neymar Jr   27     175      68      Brazil
#
#                       club  rating  value_M  wage_K preferred_foot real_face  \
# 7             FC Barcelona      88     71.5   230.0          Right       Yes
# 14883         FC Barcelona      92    109.0   260.0          Right       Yes
# 31892  Paris Saint-Germain      92    123.0   280.0          Right       Yes
# 49484  Paris Saint-Germain      92    118.5   290.0          Right       Yes
# 67254  Paris Saint-Germain      92    105.5   290.0          Right       Yes
#
#       position  jersey_number  pace  shooting  passing  dribbling  defending  \
# 7           LM           11.0  90.0      80.0     72.0       92.0       30.0
# 14883       LM           11.0  91.0      84.0     78.0       95.0       30.0
# 31892       LM           10.0  92.0      84.0     79.0       95.0       30.0
# 49484       LM           10.0  92.0      84.0     83.0       95.0       32.0
# 67254       LM           10.0  91.0      85.0     87.0       95.0       32.0
#
#        physic  heading  free_kick  ball_control  acceleration  speed  \
# 7        57.0       62         78            91            91     90
# 14883    56.0       62         79            95            93     90
# 31892    60.0       62         84            95            94     90
# 49484    59.0       62         87            95            94     90
# 67254    58.0       62         87            95            94     89
#
#        real_face_Yes  preferred_foot_Right  year
# 7                  1                     1  2016
# 14883              1                     1  2017
# 31892              1                     1  2018
# 49484              1                     1  2019
# 67254              1                     1  2020

# %%
sns.lmplot( x="age", y="value_M", data=df_n, fit_reg=False, hue='year', legend=True, height=16)
sns_plot.savefig("output.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-9bb134e05f1e> in <module>
#       1 sns.lmplot( x="age", y="value_M", data=df_n, fit_reg=False, hue='year', legend=True, height=16)
# ----> 2 sns_plot.savefig("output.png")
#
# NameError: name 'sns_plot' is not defined

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_n,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
#james rodriguez
#Álvaro Morata

# %%
df_m = df[df.id.eq(201153)] # morata

# %%
df_sa = df[df.id.eq(209331)] #salah

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_m,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_sa,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_messi,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_crist,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (16,9))
sns.set(style='darkgrid',)
 
# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "age", y = "value_M", data = df_k,
             palette = "hot", dashes = False, 
            markers = ["o", "<", ">", "^"],  legend="brief",)
 
plt.title("Name", fontsize = 20)
plt.xlabel("age", fontsize = 15)
plt.ylabel("value_M", fontsize = 15)
plt.show()

# %%
dfs = [df_n,df_messi,df_crist,df_k,df_sa,df_m]

names = pd.concat(dfs, axis=0, ignore_index=True)

# %%
names

# %%
names["name"] = names["name"].str.replace("Neymar Jr","Neymar")

# %%
names

# %%
sns.dogplot()

# %%
plt.figure(figsize=(16, 9))

g = sns.lineplot(x="age",
                 y="value_M",
                 hue='name',
                 data=names
                 ).set_title('NYC Weather Over Time')
plt.show()

#g.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
clubs = ['Chelsea' , 'Arsenal', 'Liverpool', 'Manchester City', 'Manchester United', 
         'Juventus', 'Roma', 'Napoli', 'Inter', 'Milan', 
         'Paris Sain-Germain' ,
         'FC Bayern München', 'Borussia Dortmund', 
         'Real Madrid' , 'FC Barcelona' , 'Atlético Madrid']

# %%
fifa_club_age = fifa_20.loc[fifa_20['club'].isin(clubs) & fifa_20['age']]
plt.figure(1 , figsize = (15 ,7))
sns.violinplot(x = 'club' , y = 'value_M' , data = fifa_club_age,palette='coolwarm')
plt.title('Value Distribution in famous clubs')
plt.xticks(rotation = 50)
plt.show()
